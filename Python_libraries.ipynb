# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\Admin\\Downloads\\mini_project_sales_data.csv')

# %%
#checking the columns 
df.head()
# Out:
#          Date     Product     Category    Price  Quantity Sold  Total Revenue
# 0  2024-02-04      Camera  Accessories  1652.60              8       13220.80
# 1  2024-01-14     Speaker      Gadgets  1181.49             19       22448.31
# 2  2024-02-12    Keyboard  Electronics   367.60             15        5514.00
# 3  2024-01-09       Mouse      Gadgets   333.89              2         667.78
# 4  2024-01-22  Smartphone      Gadgets   517.95              2        1035.90

# %%
df.tail()
# Out:
#            Date     Product     Category    Price  Quantity Sold  \
# 195  2024-01-22    Keyboard  Electronics  1143.78             24
# 196  2024-02-20    Keyboard      Gadgets  1857.33             11
# 197  2024-02-15  Smartwatch      Gadgets  1545.16             22
# 198  2024-01-28     Monitor  Electronics  1165.37             24
# 199  2024-02-22  Headphones  Accessories   347.36              6
#
#      Total Revenue
# 195       27450.72
# 196       20430.63
# 197       33993.52
# 198       27968.88
# 199        2084.16

# %%
#column names 
df.columns.values
# Out:
# array(['Date', 'Product', 'Category', 'Price', 'Quantity Sold',
#        'Total Revenue'], dtype=object)

# %%
#checking null values
df.isna().sum()
# Out:
# Date             0
# Product          0
# Category         0
# Price            0
# Quantity Sold    0
# Total Revenue    0
# dtype: int64

# %%
#summary
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           200 non-null    object
#  1   Product        200 non-null    object
#  2   Category       200 non-null    object
#  3   Price          200 non-null    float64
#  4   Quantity Sold  200 non-null    int64
#  5   Total Revenue  200 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.5+ KB

# %%
#states describe summary
df.describe()
# Out:
#              Price  Quantity Sold  Total Revenue
# count   200.000000      200.00000     200.000000
# mean   1263.517900       15.32000   20226.768200
# std     712.305478        8.78999   17420.027437
# min      50.790000        1.00000      59.300000
# 25%     645.715000        7.75000    6051.802500
# 50%    1217.890000       16.00000   16061.520000
# 75%    1924.385000       23.25000   29685.690000
# max    2490.460000       30.00000   69912.600000

# %%
df.Price.value_counts()
# Out:
# Price
# 1652.60    1
# 608.31     1
# 1037.48    1
# 717.24     1
# 2343.04    1
#           ..
# 435.54     1
# 1533.20    1
# 1787.91    1
# 2132.71    1
# 347.36     1
# Name: count, Length: 200, dtype: int64

# %%
df.Price.value_counts().plot(kind = 'bar',color=["orchid","salmon"])
plt.title("Total Revenue")
plt.xlabel("Product")
plt.ylabel("Category");
plt.show()

# %%
#plot pie chart 
df.Price.value_counts().plot(kind = 'pie',figsize=(8,6))
plt.legend(["Product","Category"]);
plt.show()
